# %%
class car:
    pass

# %%
# init is a constucter 
# constucter is a entity which will pass data to a class
# self alawys behaves as a pointer 
# and self is pointing to the class car


class car:
    def __init__(self, brand_name, fueltype, body_type):
        self.brand_name = brand_name
        self.fueltype = fueltype
        self.body_type = body_type
        
    def desc_car(self):
        print(self.brand_name, self.fueltype, self.body_type)

# %%
innova.body_type
# Out:
# 'suv'

# %%
innova = car('toyota', 'petrol', 'suv')
nexon = car('tata', 'petrol', 'suv')
fortuner= car('toyota', 'desiel', 'suv')

# %%
innova.desc_car()
# Out:
# toyota petrol suv

# %%
innova

# %%
innova.desc_car()
# Out:
# toyota petrol suv

# %%
innova.brand_name
# Out:
# 'toyota'

# %%
nexon.desc_car()
# Out:
# tata petrol suv

# %%
fortuner.desc_car()
# Out:
# toyota desiel suv

# %%
a = 10

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
s = 'sudh'

# %%
print(type(s))
# Out:
# <class 'str'>

# %%
class car:
        
    def test(self):
        print('this is my first method')

# %%
x = car()

# %%
x.test()
# Out:
# this is my first method

# %%
print(type(x))
# Out:
# <class '__main__.car'>

# %%
class list_parser:
    def parser(self,a):
        if type(a) == list:
            for i in a :
                print(i, end = " ")
                
    def reverse_list(self,a):
        if type(a) == list:
            for i in range(len(a),-1,-1):
                print(i,end = " ")

# %%
x = list_parser()

# %%
x.parser([1,2,3,4,5])
# Out:
# 1 2 3 4 5

# %%
x.reverse_list([1,2,3,4,5,6])
# Out:
# 6 5 4 3 2 1 0

# %%
l = [1,2,3,4]
for i in range(len(l),-1,-1):
    print(i, end = ' ')
# Out:
# 4 3 2 1 0

# %%
class list_parser:
    def parser(self,a):
        if type(a) == list:
            for i in a :
                print(i)
                
    def reverse_list(self,a):
        if type(a) == list:
            return a[::-1]

# %%
x= list_parser()

# %%
x.reverse_list([1,2,3,4,5])
# Out:
# [5, 4, 3, 2, 1]

# %%
class list_parser:
    def __init__(self,a):
        self.a = a
        
    def parser(self):
        if type(self.a) == list:
            for i in self.a :
                print(i, end = " ")
                
    def reverse_list(self):
        if type(self.a) == list:
            return self.a[::-1]

# %%
x = list_parser([1,2,3,4,5])

# %%
x.reverse_list()
# Out:
# [5, 4, 3, 2, 1]

# %%
x.parser()
# Out:
# 1 2 3 4 5

# %% [raw]
# # Create a class for dict parsing
# # 1 . give all the keys
# 2. give all the values
# 3. throw an exception in case input is not dict
# 4. to take user input and then parse key and value for dict
# 5. to insert new key value parse into dict

# %%
class dict_fun():
    def __init__(self,a):
        self.a = a
        
    def get_keys(self):
        if self.verify_input():
            return list(self.a.keys())
    
    def get_values(self):
        if self.verify_input():
            return self.a.values()
    
    def verify_input(self):
            if type(self.a) !=dict:
                raise Exception('input is not dictionary' , b)
                
    def user_input(self):
        b= eval(input())
        self.a.update(b)
        print(self.a)
        print(self.a.keys())
        
    def add_new_dict(self,b):
        if type(b) == dict:
            self.a.update(b)
        return self.a
    
    def insertion(self,k,v):
        self.a[k] = v
        return self.a
    
    def user_insertion(self):
        k = input()
        v = input()
        self.a[k] = v
        return self.a

# %%
x = dict_fun({'a':5, 'b':6 , 'c':7})

# %%
x.get_keys()

# %%
x.user_insertion()
# Out:
# 5
# 6
# {'a': 5, 'b': 6, 'c': 7, '5': '6'}

# %%
x.get_keys()

# %%
x.get_values()

# %%
x.verify_input([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_20384/2802977484.py in <module>
# ----> 1 x.verify_input([1,2,3])
#
# TypeError: verify_input() takes 1 positional argument but 2 were given

# %%
x.user_input()
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\RAKSHANDA\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_20384/1838609356.py", line 1, in <module>
#     x.user_input()
#
#   File "C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_20384/72099168.py", line 18, in user_input
#     b= eval(input())
#
#   File "<string>", line unknown
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
x.add_new_dict({"e":5, "f" : 6})
# Out:
# {'a': 5, 'b': 6, 'c': 7, '5': '6', 'e': 5, 'f': 6}

# %%
x.insertion('h' , '67')
# Out:
# {'a': 5, 'b': 6, 'c': 7, '5': '6', 'e': 5, 'f': 6, 'h': '67'}

# %%
class dict_fun():
    def __init__(self,a):
        self.a = a
        
    def get_keys(self):
        if self.verify_input():
            return list(self.a.keys())
    
    def get_values(self):
        if self.verify_input():
            return self.a.values()
    
    def verify_input(self):
            if type(self.a) !=dict:
                raise Exception('input is not dictionary' , self.a)
            return 1

# %%
d = dict_fun({'a': 5, 'b': 6, 'c': 7, 'h': '67'})

# %%
d.get_keys()
# Out:
# ['a', 'b', 'c', 'h']

# %%
# Final_Program

class Dict_function :
    def __init__(self,a):
        self.a = a
        
    def verify_dict(self):
        if type(self.a) != dict:
            raise Exception(self.a , 'is not a dictionary')
        return 1
    
    
    def get_keys(self):
        if self.verify_dict():
            return list(self.a.keys())
        
    def get_values(self):
        if self.verify_dict():
            return list(self.a.values())
        
        
    def user_input(self):
        b = eval(input())
        self.a.update(b)
        return self.a,
    
    def insertion(self,**kwargs):
        for k , v in kwargs.items():
            self.a[k] = v
        return self.a

# %%
x= Dict_function({'a': 5, 'b': 6, 'c': 7, 'h': '67'})

# %%
x.get_keys()
# Out:
# ['a', 'b', 'c', 'h']

# %%
x.get_values()
# Out:
# [5, 6, 7, '67']

# %%
x.user_input()
# Out:
# {'g' : 45}
# ({'a': 5, 'b': 6, 'c': 7, 'h': '67', 'g': 45},)

# %%
x.insertion(name = 'raksha', g = 35)
# Out:
# {'a': 5, 'b': 6, 'c': 7, 'h': '67', 'g': 35, 'name': 'raksha'}

# %%
open('mydict.py', 'w')
# Out:
# <_io.TextIOWrapper name='mydict.py' mode='w' encoding='cp1252'>
