# %%
len('sudh')
# Out:
# 4

# %%
print("sdasd")
# Out:
# sdasd

# %%
def test():
    pass

# %%
def test1():
    print('this is my first fun')

# %%
test1()
# Out:
# this is my first fun

# %%
a = test1()
# Out:
# this is my first fun

# %%
a + "sudh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_38816/2234722170.py in <module>
# ----> 1 a + "sudh"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
type(test1())
# Out:
# this is my first fun
# NoneType

# %%
str(a)
# Out:
# 'None'

# %%
def test2():
    return "this is my first fun"

# %%
type(test2())
# Out:
# str

# %%
test2()+' sudh'
# Out:
# 'this is my first fun sudh'

# %%
def test3():
    return 342

# %%
type(test3())
# Out:
# int

# %%
# print alawys type to return nontype

# %%
def test4():
    return 4,3,'sudh',[1,2,3,4]

# %%
test4()
# Out:
# (4, 3, 'sudh', [1, 2, 3, 4])

# %%
type(test4())
# Out:
# tuple

# %%
b = test4()

# %%
b
# Out:
# (4, 3, 'sudh', [1, 2, 3, 4])

# %%
b[1]
# Out:
# 3

# %%
b[3]
# Out:
# [1, 2, 3, 4]

# %%
test4()
# Out:
# (4, 3, 'sudh', [1, 2, 3, 4])

# %%
a = 1
b=5 
c='sudh'
d=[34,33,12,53]

# %%
a,b,c,d=1,'sudh',[1,3,5],5

# %%
x,y,u,v ,d = test4()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_38816/440853695.py in <module>
# ----> 1 x,y,u,v ,d = test4()
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
x,y,u,v = test4()

# %%
u
# Out:
# 'sudh'

# %%
v
# Out:
# [1, 2, 3, 4]

# %%
x
# Out:
# 4

# %%
y
# Out:
# 3

# %%
def test5():
    a = 6*7/6
    return a

# %%
test5()
# Out:
# 7.0

# %%
len('fsds')
# Out:
# 4

# %%
l = [3,4,5,6,7,7,'sudh',[1,2,3,4,56,78]]

# %%
def test6(a):
    n = []
    if type(a) == list:
        for i in a:
            if type(i) == int:
                n.append(i)
    return n

# %%
test6([3,4,5,6,7,7,'sudh',[1,2,3,4,56,78]])
# Out:
# [3, 4, 5, 6, 7, 7]

# %%
type(test6([3,4,5,6,7,7,'sudh',[1,2,3,4,56,78]]))
# Out:
# list

# %%
def test7(a):
    if type(a) == dict:
        for i in a.keys():
            print(i)

# %%
test7({"a" : 'raksha' , 'b' : 'raj', "c" : 'sudh'})
# Out:
# a
# b
# c

# %%
type(test7({"a" : 'raksha' , 'b' : 'raj', "c" : 'sudh'}))
# Out:
# a
# b
# c
# NoneType

# %%
def test7 (c) :
    if type(c) == dict:
        return c.keys()
    else:
        return ('u have not passed a dict')

# %%
test7({"a" : 'raksha' , 'b' : 'raj'})
# Out:
# dict_keys(['a', 'b'])

# %%
s = {"a" : 'raksha' , 'b' : 'raj'}  
for i in s.keys():
    print(i)
# Out:
# a
# b

# %%
def test8(l1,l2):
    if type(l1) == list and type(l2) == list:
        return l1+l2

# %%
test8([1,2,3], [2,3,4])
# Out:
# [1, 2, 3, 2, 3, 4]

# %%
def test8(l1,l2):
    if type(l1) == list and type(l2) == list:
        return l1.extend(l2)
    else:
        return 'either of ur data is not a list'

# %%
test8([1,2,3], [2,3,4])

# %%
n = test8([1,2,3], [2,3,4])

# %%
a = [2,3,4,5]
b = [4,5,6,7,8666]

test8(a,b)
a
# Out:
# [2, 3, 4, 5, 4, 5, 6, 7, 8666]

# %%
def test9(l1,l2):
    if type(l1) == list and type(l2) == list:
        l1.extend(l2)
        return l1
    else:
        return 'either of ur data is not a list'

# %%
test9([1,2,3], [2,3,4])
# Out:
# [1, 2, 3, 2, 3, 4]

# %%
n = 5
for i in range(0,n):
    for j in range(0,i+1):
        print("*", end = '')
    print("\r")
# Out:
# *
# **
# ***
# ****
# *****

# %%
def test10(n):
    """ this is a function which will help u to create a triangle with any no of rows"""
    for i in range(0,n):
        for j in range(0,i+1):
            print("*", end = '')
        print("\r")

# %%
test10(5)
# Out:
# *
# **
# ***
# ****
# *****

# %%
help(test10)
# Out:
# Help on function test10 in module __main__:
#
# test10(n)
#     this is a function which will help u to create a triangle with any no of rows
