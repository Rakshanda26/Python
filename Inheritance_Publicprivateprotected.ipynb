# %%
class xyz :
    def __init__(self, a,b,c):
        self.a = a
        self.b = b
        self.c = c
        
    def test(self):
        print('this is my first print method of xyz class')
        
    def test1(self):
        print('this is my test2 method of xyz class ')
    
    def test2(self):
        print('this is my test3 method of xyz class')

# %%
 p = xyz(1,2,3)

# %%
p.test1()
# Out:
# this is my test2 method of xyz class

# %%
class xyz1(xyz):
    pass

# %%
q = xyz1(1,2,3)

# %%
q.test1()
# Out:
# this is my test2 method of xyz class

# %%
q = xyz1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_2300/2225742902.py in <module>
# ----> 1 q = xyz1()
#
# TypeError: __init__() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
class xyz1(xyz):
    def test(self):
        print('this is the test method available in xyz1')

# %%
g = xyz1(1,2,3)

# %%
g.test()
# Out:
# this is the test method available in xyz1

# %%
class xyz :
    def __init__(self, a,b,c):
        self.a = a
        self.b = b
        self.c = c
        
    def test(self):
        print('this is my first print method of xyz class')
        
    
class xyz1:
    def __init__(self, p,q,r):
        self.p = p
        self.q = q
        self.r = r
    
    def test1(self):
        print('this is a meth from class xyz1')
    
class child(xyz1,xyz):
    pass

#class child(xyz1,xyz):
#    pass

# variable wise it will work for first argument
# method wise it will work for all the methods

# %%
n = child(4,5,6)

# %%
n.test()
# Out:
# this is my first print method of xyz class

# %%
n.test1()
# Out:
# this is a meth from class xyz1

# %%
# Multiple Inheritance
class xyz :
    def __init__(self, a,b,c):
        self.a = a
        self.b = b
        self.c = c
        
    def test(self):
        print('this is my first print method of xyz class')
        
    
class xyz1:
    def __init__(self, p,q,r):
        self.p = p
        self.q = q
        self.r = r
    
    def test1(self):
        print('this is a meth from class xyz1')
    
class child(xyz1,xyz):
    def __init__(self,*args, **kwargs):
        xyz.__init__(self,*args)
        xyz1.__init__(self,**kwargs)

# %%
n = child(4,5,6,p=5, q=6, r =7)

# %%
n.a
# Out:
# 4

# %%
n.p
# Out:
# 5

# %%
n.test()
# Out:
# this is my first print method of xyz class

# %%
n.test1()
# Out:
# this is a meth from class xyz1

# %%
# Multilevel Inheritance
class xyz :
    def __init__(self, a,b,c):
        self.a = a
        self.b = b
        self.c = c
        
    def test(self):
        print('this is my first print method of xyz class')
        
    
class xyz1(xyz):

    def test1(self):
        print('this is a meth from class xyz1')
        
class xyz2(xyz1):
    def test2(self):
        print('this is meth from xlass xyz2')
    
class xyz3(xyz2):
    def test3(self):
        print('this is meth from xyz3')

# %%
v = xyz2(4,5,6)

# %%
v = xyz3(5,6,7)

# %%
v.test3()
# Out:
# this is meth from xyz3

# %%
class File:
    def write(self,data):
        f = open('inherit.txt', "w")
        f.write(data)
        f.close()
    
    def read(self):
        f = open('inherit.txt', 'r')
        f.seek(0)
        print(f.read())
    
class child(File):
    def test(self):
        pass

# %%
x = File()

# %%
x.write('Writing the file')

# %%
x.read()
# Out:
# Writing the file

# %%
x1 = child()

# %%
x1.read()
# Out:
# this is my first write method

# %%
import logging
logging.basicConfig(filename ='List.log',level=logging.DEBUG,format="%(asctime)s,%(levelname)s,%(message)s",filemode='w')

class File:
    def __init__(self,filename):
        logging.info('Creating file Instance variable')
        self.file = filename
        
    def read(self):
        logging.info('Executing read method')
        try:
            with open(f"{self.file}.txt" , 'r') as f:
                data = f.read()
                return data
        except FileNotFoundError as e:
            logging.error('Error occured while opening the file')
            logging.exception(f"Error is {s}")
               
    def write(self,data):
        logging.info('Executing write method')
        try:
            with open(f"{self.file}.txt", "w") as f:
                data = f.write(data)
                f.close()
                
        except FileNotFoundError as e:
            logging.error('Something is going wrong')
            
class Child(File):
    def test(self):
        print('this is child class')

# %%
x = Child('inherit')

# %%
x.write('writing file')

# %%
x.read()
# Out:
# 'writing file'

# %%
Obj = File('inherit')

# %%
Obj.read()
# Out:
# 'writing file'

# %%
Obj.write('writing file')

# %%
class test:
    def __init__(self,a,b,c):
        self.a =a
        self.b = b
        self.c = c

class test1(test):
    pass

u = test(4,5,6)

# %%
v = test1(3,4,5)

# %%
v.a
# Out:
# 3

# %%
# _a = protected  = 
class test:
    def __init__(self):
        self._a = 4

class test1(test):
    def __init__(self) :
        self._a = 7

u = test()

# %%
u._a
# Out:
# 4

# %%
v = test1()

# %%
v._a
# Out:
# 7

# %%
# _a = protected  = u can use inside classes and inside subclasses but outside that subclass not able to use 
class test:
    def __init__(self):
        self.__a = 4

class test1(test):
    def __init__(self) :
        self.__a = 7

u = test()

# %%
u.__a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_2300/3701111835.py in <module>
# ----> 1 u.__a
#
# AttributeError: 'test' object has no attribute '__a'

# %%
v =test1()
v.__a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_2300/4219025645.py in <module>
#       1 v =test1()
# ----> 2 v.__a
#
# AttributeError: 'test1' object has no attribute '__a'

# %%
# protected : inside class and inside subclass(child classes ) 
# private : Just within the class (not child class)
# public : can acess from anyclasses anywhere 
# encapsulation : others not able acces any data without u r permission 
class test:
    def __init__(self,a,b,c):
        self._a =a
        self.__b = b
        self.c = c
        
class test1(test):
    pass
        
v = test(4,5,6)

# %%
v._a
# Out:
# 4

# %%
# If I want to access private variable then use 
v.__b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_2300/4134146159.py in <module>
#       1 # If I want to access private variable then use
# ----> 2 v.__b
#
# AttributeError: 'test' object has no attribute '__b'

# %%
# If I want to access private variable then use 
v._test__b
# Out:
# 5

# %%
v.c
# Out:
# 6

# %%
u = test1(3,4,5)

# %%
u.c
# Out:
# 5

# %%
u._a
# Out:
# 3

# %%
u._test1__b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_2300/4083783106.py in <module>
# ----> 1 u._test1__b
#
# AttributeError: 'test1' object has no attribute '_test1__b'

# %%
u._test__b
# Out:
# 4

# %%
class bonouscalculater:
