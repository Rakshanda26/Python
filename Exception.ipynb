# %%
a = 5
a/10
# Out:
# 0.5

# %%
a/0
print('this is my prog')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_13728/3450635350.py in <module>
# ----> 1 a/0
#       2 print('this is my prog')
#
# ZeroDivisionError: division by zero

# %%
a = 5
b = int(input())
a/b
# Out:
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_13728/4083926819.py in <module>
#       1 a = 5
#       2 b = int(input())
# ----> 3 a/b
#
# ZeroDivisionError: division by zero

# %%
f = open('test.txt', 'w')

# %%
f.write('fsdsfdsfsa')
# Out:
# 10

# %%
f.close()

# %%
f = open('test.txt', 'r')

# %%
f.write('fsfasdf sdfsdf dsfasf')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_13728/1887384898.py in <module>
# ----> 1 f.write('fsfasdf sdfsdf dsfasf')
#
# UnsupportedOperation: not writable

# %%
try :
    f = open('test.txt', "r")
    f.write('fsfsdsfa')

except :
    print('there was a mistake')
print('this is  my code')
# Out:
# there was a mistake
# this is  my code

# %%
l = [4,5,6,7,6,8,0]

try : 
    for i range(len(l)):
          print(l)
except:
    print('this is my code')
# Out:
#   File "C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_13728/4068923912.py", line 4
#     for i range(len(l)+1):
#           ^
# SyntaxError: invalid syntax

# %%
l = [4,5,6,7,6,8,0]
for i in range(len(l)+1):
    print(l[i])
# Out:
# 4
# 5
# 6
# 7
# 6
# 8
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_13728/795944826.py in <module>
#       1 l = [4,5,6,7,6,8,0]
#       2 for i in range(len(l)+1):
# ----> 3     print(l[i])
#
# IndexError: list index out of range

# %%
l = [4,5,6,7,6,8,0]
try : 
    for i in range(len(l)+1):
        print(l[i])
except :
    print('this is my code')
print('fdsfasdfasdffsadfasdsafasd')
# Out:
# 4
# 5
# 6
# 7
# 6
# 8
# 0
# this is my code
# fdsfasdfasdffsadfasdsafasd

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_13728/2874912419.py in <module>
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
l = [4,5,6,7,6,8,0]
try : 
    for i in range(len(l)+1):
        print(l[i])
except Exception as e:
    print( e)
print('fdsfasdfasdffsadfasdsafasd')
# Out:
# 4
# 5
# 6
# 7
# 6
# 8
# 0
# list index out of range
# fdsfasdfasdffsadfasdsafasd

# %%
try :
    a = int(input())
    b = int(input())
    
except Exception as e:
    print(e)

print('my code is working even after error')
# Out:
# fasfa
# invalid literal for int() with base 10: 'fasfa'
# my code is working even after error

# %%
try : 
    f = open('test' , 'r')
    f.write('this is my code with except handling')
    print('this is my code after write ops')

except Exception as e :
    print(e)
try:    
    l = [1,2,3,4]
    for i in l:
        print(i)
except :
    print('this is my handler for loop')
# Out:
# [Errno 2] No such file or directory: 'test'
# 1
# 2
# 3
# 4

# %%
try :
    d = {'key1' : 'sudh' , 'key2': [1,2,3,4,5], 'key3' : (4,5,6,7)}
    d['key4'] : int(input())
        
except Exception as e:
    print(e)
# Out:
# tew
# invalid literal for int() with base 10: 'tew'

# %%
d = {'key1' : 'sudh' , 'key2': [1,2,3,4,5], 'key3' : (4,5,6,7)}
d['key4'] : int(input())
# Out:
# rew
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_13728/3949761922.py in <module>
#       1 d = {'key1' : 'sudh' , 'key2': [1,2,3,4,5], 'key3' : (4,5,6,7)}
# ----> 2 d['key4'] : int(input())
#
# ValueError: invalid literal for int() with base 10: 'rew'

# %%
try :
    d = {'key1' : 'sudh' , 'key2': [1,2,3,4,5], 'key3' : (4,5,6,7)}
    d['key4'] : int(input())
    f = open('test3.txt' , 'r')   
except ValueError as e:
    print(e)
# Out:
# 44
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_13728/876450867.py in <module>
#       2     d = {'key1' : 'sudh' , 'key2': [1,2,3,4,5], 'key3' : (4,5,6,7)}
#       3     d['key4'] : int(input())
# ----> 4     f = open('test3.txt' , 'r')
#       5 except ValueError as e:
#       6     print(e)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test3.txt'

# %%
try :
    d = {'key1' : 'sudh' , 'key2': [1,2,3,4,5], 'key3' : (4,5,6,7)}
    d['key4'] : int(input())
    f = open('test3.txt' , 'r')   
except Exception as e:
    print(e)
# Out:
# 44
# [Errno 2] No such file or directory: 'test3.txt'

# %%
try :
    d = {'key1' : 'sudh' , 'key2': [1,2,3,4,5], 'key3' : (4,5,6,7)}
    d['key4'] : int(input())
    f = open('test3.txt' , 'r')   
except ValueError as e:
    print(e)
    
except FileNotFoundError as e:
    print(e)
# Out:
# 66
# [Errno 2] No such file or directory: 'test3.txt'

# %%
try :
    d = {'key1' : 'sudh' , 'key2': [1,2,3,4,5], 'key3' : (4,5,6,7)}
    d['key4'] : int(input())
    f = open('test3.txt' , 'r') 

except Exception as ee:
    print('This is my exception class',ee)
except ValueError as e:
    print(e)
    
except FileNotFoundError as e:
    print(e)
# Out:
# 88
# This is my exception class [Errno 2] No such file or directory: 'test3.txt'

# %%
try :
    d = {'key1' : 'sudh' , 'key2': [1,2,3,4,5], 'key3' : (4,5,6,7)}
    d['key4'] : int(input())
    f = open('test3.txt' , 'r') 
    
except ValueError as e:
    print(e)
    
except FileNotFoundError as e:
    print('testing2',e)

except Exception as ee:
    print('This is my exception class',ee)
# Out:
# 43
# testing2 [Errno 2] No such file or directory: 'test3.txt'

# %%
try :
    f = open('test1.txt' , 'w')
    f.write('this is my code in try')
    
except Exception as e:
    print('this will handle an error' ,e )

else:
    print('this will execute once my try block will be executed successfully')
    f.close()
# Out:
# this will execute once my try block will be executed successfully

# %%
try :
    f = open('test4.txt' , 'r')
except Exception as e:
    print('fadfas',e)
else:
    print('do this on successful execution of try block')
    
finally :
    print('do this for sure, This will execute all the time even if try fail or pass')
# Out:
# fadfas [Errno 2] No such file or directory: 'test4.txt'
# do this for sure, This will execute all the time even if try fail

# %%
try :
    f = open('test4.txt' , 'w')
except Exception as e:
    print('fadfas',e)
else:
    print('do this on successful execution of try block')
    
finally :
    print('do this for sure, This will execute all the time even if try fail')
# Out:
# do this on successful execution of try block
# do this for sure, This will execute all the time even if try fail

# %%
try :
    f = open('test4.txt' , 'w')
except Exception as e:
    print('fadfas',e)
else:
    print('do this on successful execution of try block')
    
finally :
    print('do this for sure, This will execute all the time even if try fail')
    f = open('test5.txt' , 'r')
# Out:
# do this on successful execution of try block
# do this for sure, This will execute all the time even if try fail
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_13728/493838449.py in <module>
#       8 finally :
#       9     print('do this for sure, This will execute all the time even if try fail')
# ---> 10     f = open('test5.txt' , 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test5.txt'

# %%
try :
    f = open('test4.txt' , 'w')
except Exception as e:
    print('fadfas',e)
else:
    print('do this on successful execution of try block')
    
finally :
    print('do this for sure, This will execute all the time even if try fail')
    try :
        f = open('test5.txt' , 'r')
    except Exception as e :
        print(e)
# Out:
# do this on successful execution of try block
# do this for sure, This will execute all the time even if try fail
# [Errno 2] No such file or directory: 'test5.txt'

# %%
try :
    f = open('test4.txt' , 'w')
except Exception as e:
    print('fadfas',e)
else:
    print('do this on successful execution of try block')
    
finally :
    print('do this for sure, This will execute all the time even if try fail')
    try :
        f = open('test5.txt' , 'r')
    except Exception as e :
        print(e)
        
    finally:
        print('This will come to this block for sure')
# Out:
# do this on successful execution of try block
# do this for sure, This will execute all the time even if try fail
# [Errno 2] No such file or directory: 'test5.txt'
# This will come to this block for sure

# %%
def askint():
    a = int(input())
    return a

askint()
# Out:
# fas
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_13728/2961965484.py in <module>
#       3     return a
#       4
# ----> 5 askint()
#
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_13728/2961965484.py in askint()
#       1 def askint():
# ----> 2     a = int(input())
#       3     return a
#       4
#       5 askint()
#
# ValueError: invalid literal for int() with base 10: 'fas'

# %%
def askint():
    try :
        a = int(input())
        return a
    except Exception as e:
        print(e)

askint()
# Out:
# tsfas
# invalid literal for int() with base 10: 'tsfas'

# %%
def askint():
    try:
        while True :
            a = int(input('Enter the number:'))
    except Exception as e:
        print(e)
askint()
# Out:
# Enter the number:fdf
# invalid literal for int() with base 10: 'fdf'

# %%
def askint():
        flag = True
        while flag :
            try :
                a = int(input('Enter the number:'))
                return a
                flag = 'false'
            except Exception as e:
                print(e)
askint()
# Out:
# Enter the number:te
# invalid literal for int() with base 10: 'te'
# Enter the number:tre
# invalid literal for int() with base 10: 'tre'
# Enter the number:ete
# invalid literal for int() with base 10: 'ete'
# Enter the number:ete
# invalid literal for int() with base 10: 'ete'
# Enter the number:5
# 5

# %%
def integer():
    while True:
        '''This function asks for an integer unless provided otherwise'''
        try:
            x = int(input())
            break
        except Exception as e :
            print('enter the input again :- ',e)

integer()
# Out:
# enter the input again :-  invalid literal for int() with base 10: ''
# 5

# %%
def getint():
    while True:
        try:
            a = int(input())
        except Exception as e:
            print(e)
            continue
        if a < 0 :
            print('enter a positive no')
            continue
        else:
            break
        
        return a
    
getint()
# Out:
# f
# invalid literal for int() with base 10: 'f'
# f
# invalid literal for int() with base 10: 'f'
# f
# invalid literal for int() with base 10: 'f'
# -5
# enter a positive no
# 5

# %%
def askint():
    while True:
        try:
            a = int(input())
            break
        except Exception as e:
            print('Enter a number only' , e)
            continue
askint()
# Out:
# ff
# Enter a number only invalid literal for int() with base 10: 'ff'
# ff
# Enter a number only invalid literal for int() with base 10: 'ff'
# ff
# Enter a number only invalid literal for int() with base 10: 'ff'
# d5
# Enter a number only invalid literal for int() with base 10: 'd5'
# 5

# %%
a = 6/10

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_9160/2874912419.py in <module>
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
def test(a):
    if a < 0:
        raise Exception('you have entered a negative value' , a)
    return a

# %%
test(-4)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_9160/2430745927.py in <module>
# ----> 1 test(-4)
#
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_9160/3035122755.py in test(a)
#       1 def test(a):
#       2     if a < 0:
# ----> 3         raise Exception('you have entered a negative value' , a)
#       4     return a
#
# Exception: ('you have entered a negative value', -4)

# %%
# using existing excep clss and override it 
def test(a):
    if a < 0:
        raise ValueError('you have entered a negative value' , a)
    return a

# %%
test(-4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_9160/2430745927.py in <module>
# ----> 1 test(-4)
#
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_9160/626507129.py in test(a)
#       2 def test(a):
#       3     if a < 0:
# ----> 4         raise ValueError('you have entered a negative value' , a)
#       5     return a
#
# ValueError: ('you have entered a negative value', -4)

# %%
try :
    a = int(input())
    test(a)
except Exception as e:
    print('calling my raise exception',e)
# Out:
# -4
# calling my raise exception ('you have entered a negative value', -4)
