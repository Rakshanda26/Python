# %%
s = "sudh"

# %%
type(s)
# Out:
# str

# %%
s[0]
# Out:
# 's'

# %%
s[-1]
# Out:
# 'h'

# %%
s[2]
# Out:
# 'd'

# %%
s[3]
# Out:
# 'h'

# %%
s[-2]
# Out:
# 'd'

# %%
s[-3]
# Out:
# 'u'

# %%
s[-2]
# Out:
# 'd'

# %%
s[-4]
# Out:
# 's'

# %%
a = "my name is sudh"

# %%
a[0]
# Out:
# 'm'

# %%
len(a)
# Out:
# 15

# %%
a
# Out:
# 'my name is sudh'

# %%
a[0:10]
# Out:
# 'my name is'

# %%
a[0:]
# Out:
# 'my name is sudh'

# %%
b = 'ineuron'

# %%
b[0:3]
# Out:
# 'ine'

# %%
b[0:300]
# Out:
# 'ineuron'

# %%
a[0:100]
# Out:
# 'my name is sudh'

# %%
b[300]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_9308/2380424124.py in <module>
# ----> 1 b[300]
#
# IndexError: string index out of range

# %%
b
# Out:
# 'ineuron'

# %%
b[-1]
# Out:
# 'n'

# %%
b[-1:-4]
# Out:
# ''

# %%
b[0:4]
# Out:
# 'ineu'

# %%
a = "kumar"

# %%
a[0:3]
# Out:
# 'kum'

# %%
a[0:300]
# Out:
# 'kumar'

# %%
a[0:300:1]
# Out:
# 'kumar'

# %%
a[-1:-100:-1]
# Out:
# 'ramuk'

# %%
a[0:300:2]
# Out:
# 'kmr'

# %%
a[0:300:3]
# Out:
# 'ka'

# %%
a
# Out:
# 'kumar'

# %%
a[0:100:-1]
# Out:
# ''

# %%
a
# Out:
# 'kumar'

# %%
a[-1:-4]
# Out:
# ''

# %%
a[-1:-4:-1]
# Out:
# 'ram'

# %%
a[0:-10:-1]
# Out:
# 'k'

# %%
a[::]
# Out:
# 'kumar'

# %%
a[::-1]
# Out:
# 'ramuk'

# %%
a[:8]
# Out:
# 'kumar'

# %%
a[-2:]
# Out:
# 'ar'

# %%
a
# Out:
# 'kumar'

# %%
a[-2:-1]
# Out:
# 'a'

# %%
a[1:2]
# Out:
# 'u'

# %%
a
# Out:
# 'kumar'

# %%
a[::-1]
# Out:
# 'ramuk'

# %%
a[-1::-1]
# Out:
# 'ramuk'

# %%
a = "I am working with CG"

# %%
a[::-1]
# Out:
# 'GC htiw gnikrow ma I'

# %%
a
# Out:
# 'I am working with CG'

# %%
a[-5:5]
# Out:
# ''

# %%
a[-5:5:-1]
# Out:
# 'tiw gnikro'

# %%
a[0:100:3]
# Out:
# 'Imoi tC'

# %%
"sudh"*3
# Out:
# 'sudhsudhsudh'

# %%
"sudh" +"kumar"
# Out:
# 'sudhkumar'

# %%
a
# Out:
# 'I am working with CG'

# %%
len(a)
# Out:
# 20

# %%
a
# Out:
# 'I am working with CG'

# %%
a.find('a')
# Out:
# 2

# %%
a.find('Ia')
# Out:
# -1

# %%
a.find('in')
# Out:
# 9

# %%
a.count('i')
# Out:
# 2

# %%
a
# Out:
# 'I am working with CG'

# %%
a.split()
# Out:
# ['I', 'am', 'working', 'with', 'CG']

# %%
type(a.split())
# Out:
# list

# %%
l = a.split()

# %%
l
# Out:
# ['I', 'am', 'working', 'with', 'CG']

# %%
l[0]
# Out:
# 'I'

# %%
l[3]
# Out:
# 'with'

# %%
l[2]
# Out:
# 'working'

# %%
l[4]
# Out:
# 'CG'

# %%
len(l)
# Out:
# 5

# %%
a
# Out:
# 'I am working with CG'

# %%
a.split('wo')
# Out:
# ['I am ', 'rking with CG']

# %%
a.upper()
# Out:
# 'I AM WORKING WITH CG'

# %%
s = "sUdh"

# %%
s.swapcase()
# Out:
# 'SuDH'

# %%
s.title()
# Out:
# 'Sudh'

# %%
s.capitalize()
# Out:
# 'Sudh'

# %%
b = "sudh"
c = "ineuron"

# %%
b.join(c)
# Out:
# 'isudhnsudhesudhusudhrsudhosudhn'

# %%
" ".join("sudh")
# Out:
# 's u d h'

# %%
reversed("sudh")

# %%
for i in reversed("sudh"):
    print(i)
# Out:
# h
# d
# u
# s

# %%
s = "sudh"
s[::-1]
# Out:
# 'hdus'

# %%
s = " sudh "

# %%
s.rstrip()
# Out:
# ' sudh'

# %%
s.lstrip()
# Out:
# 'sudh '

# %%
s.strip()
# Out:
# 'sudh'

# %%
s = "sudh"

# %%
s.replace("u" , "xyz")
# Out:
# 'sxyzdh'

# %%
s.replace('t','xys')
# Out:
# 'sudh'

# %%
"sudh\tkumar".expandtabs()
# Out:
# 'sudh    kumar'

# %%
s= 'sudh'

# %%
s.center(40, '#')
# Out:
# '##################sudh##################'

# %%
s.isupper()
# Out:
# False

# %%
s
# Out:
# 'sudh'

# %%
s = "sudh"

# %%
s.islower()
# Out:
# True

# %%
s.isspace()
# Out:
# False

# %%
s = "  "

# %%
s.isspace()
# Out:
# True

# %%
s= "  sudh"

# %%
s.isspace()
# Out:
# False

# %%
s= "sudh123"

# %%
s.isdigit()
# Out:
# False

# %%
s= "123"

# %%
s.isdigit()
# Out:
# True

# %%
s = "sudh"

# %%
s.endswith('h')
# Out:
# True

# %%
s.startswith('t')
# Out:
# False

# %%
s.startswith('s')
# Out:
# True

# %%
s.istitle()
# Out:
# False

# %%
s.isalpha()
# Out:
# True

# %%
s
# Out:
# 'sudh'

# %%
s.encode()
# Out:
# b'sudh'

# %%
l = ['sudh' , "kumar", 34, 45.50, True, 4+6j]

# %%
type(l)
# Out:
# list

# %%
l[-1]
# Out:
# (4+6j)

# %%
l[0]
# Out:
# 'sudh'

# %%
l[-5]
# Out:
# 'kumar'

# %%
l
# Out:
# ['sudh', 'kumar', 34, 45.5, True, (4+6j)]

# %%
l[0:4]
# Out:
# ['sudh', 'kumar', 34, 45.5]

# %%
l[::-1]
# Out:
# [(4+6j), True, 45.5, 34, 'kumar', 'sudh']

# %%
l[-1:6]
# Out:
# [(4+6j)]

# %%
l[0][1]
# Out:
# 'u'

# %%
l[3]
# Out:
# 45.5

# %%
l[4].real
# Out:
# 1

# %%
l[4]
# Out:
# True

# %%
l
# Out:
# ['sudh', 'kumar', 34, 45.5, True, (4+6j)]

# %%
l[5]
# Out:
# (4+6j)

# %%
l[5].imag
# Out:
# 6.0

# %%
l1 = ['sudh','kumar',3452]
l2 = ["xyz",'pqr', 324.34]

# %%
l1+l2
# Out:
# ['sudh', 'kumar', 3452, 'xyz', 'pqr', 324.34]

# %%
l1 +'sudh'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_9308/1104314627.py in <module>
# ----> 1 l1 +'sudh'
#
# TypeError: can only concatenate list (not "str") to list

# %%
l1 +["sudh"]
# Out:
# ['sudh', 'kumar', 3452, 'sudh']

# %%
l1*2
# Out:
# ['sudh', 'kumar', 3452, 'sudh', 'kumar', 3452]

# %%
l1
# Out:
# ['sudh', 'kumar', 3452]

# %%
l1
# Out:
# ['sudh', 'kumar', 3452]

# %%
l1[0].replace('sudh','kumar')
# Out:
# 'kumar'

# %%
l1
# Out:
# ['sudh', 'kumar', 3452]

# %%
l1
# Out:
# ['sudh', 'kumar', 3452]

# %%
l1[0]='433q42'

# %%
l1
# Out:
# ['433q42', 'kumar', 3452]

# %%
l1[1].replace('k','s')
# Out:
# 'sumar'

# %%
s = "sudh"

# %%
#string objects are immutable
s[0] = "k"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\RAKSHA~1\AppData\Local\Temp/ipykernel_9308/4082584902.py in <module>
#       1 #string objects are immutable
# ----> 2 s[0] = "k"
#
# TypeError: 'str' object does not support item assignment

# %%
l1
# Out:
# ['433q42', 'kumar', 3452]

# %%
len(l1)
# Out:
# 3

# %%
'kumar' in l1
# Out:
# True

# %%
l2
# Out:
# ['xyz', 'pqr', 324.34]

# %%
l2.append("sudh")

# %%
l2
# Out:
# ['xyz', 'pqr', 324.34, 'sudh']

# %%
l2.pop()
# Out:
# 'sudh'

# %%
l2
# Out:
# ['xyz', 'pqr', 324.34]

# %%
l2.append(343)

# %%
l2
# Out:
# ['xyz', 'pqr', 324.34, 343]

# %%
l2.insert(1,"rakshanda")

# %%
l2
# Out:
# ['xyz', 'rakshanda', 'pqr', 324.34, 343]

# %%
l2.insert(3,[1,2,3,4])

# %%
l2
# Out:
# ['xyz', 'rakshanda', 'pqr', [1, 2, 3, 4], 324.34, 343]

# %%
l2[::-1]
# Out:
# [343, 324.34, [1, 2, 3, 4], 'pqr', 'rakshanda', 'xyz']

# %%
l2.reverse()

# %%
l2
# Out:
# [343, 324.34, [1, 2, 3, 4], 'pqr', 'rakshanda', 'xyz']

# %%
l1
# Out:
# ['433q42', 'kumar', 3452]

# %%
l2
# Out:
# [343, 324.34, [1, 2, 3, 4], 'pqr', 'rakshanda', 'xyz']

# %%
l2[2][3]
# Out:
# 4

# %%
l2
# Out:
# [343, 324.34, [1, 2, 3, 4], 'pqr', 'rakshanda', 'xyz']

# %%
l2.count('rakshanda')
# Out:
# 1

# %%
l2.count('sf')
# Out:
# 0

# %%
l2.append([3,4,4,2])

# %%
l2
# Out:
# [343, 324.34, [1, 2, 3, 4], 'pqr', 'rakshanda', 'xyz', [3, 4, 4, 2]]

# %%
l1
# Out:
# ['433q42', 'kumar', 3452]

# %%
l1.extend([2,4,45.3,True])

# %%
l1
# Out:
# ['433q42', 'kumar', 3452, 2, 4, 45.3, True]

# %%
key = ("name", "mob_no", "email_id")
value = "sudh"

# %%
d1 = {'key1': 'raksha'}

# %%
d1
# Out:
# {'key1': 'raksha'}

# %%
d = d1.fromkeys(key,value)

# %%
d
# Out:
# {'name': 'sudh', 'mob_no': 'sudh', 'email_id': 'sudh'}
