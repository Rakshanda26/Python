# %%
a = 10

# %%
if a < 15 :
    print('fsdfsfds')
# Out:
# fsdfsfds

# %%
a<15
# Out:
# True

# %%
if a < 15 :
    pass

# %%
if a < 15 :
    print("my name is raju")
# Out:
# my name is raju

# %%
if 24 < 15 :
    print('my name is sudh')

# %%
24 < 15
# Out:
# False

# %%
if 10 <3 :
    print('10 is lesser that 3')
else :
    print('it statement is wrong')
# Out:
# it statement is wrong

# %%
if  2 <3 :
    print('2 is lesser that 3')
else :
    print('it statement is wrong')
# Out:
# 10 is lesser that 3

# %%
income = int(input())
if income < 50 :
    print('I will be able to buy phone')
elif income < 70 :
    print("I will be able to buy car")
elif income < 90 :
    print ('I will be able to rent a house')
else :
    print('I wont be able to buy anything')
# Out:
# 100
# I wont be able to buy anything

# %%
total_price = int(input())
if total_price > 20000:
    discount = total_price * 0.20
    print('Discount will be', discount)
elif total_price <=7000:
    discount = total_price *.05
    print('discount will be', discount)
else:
    print('wont be able to give discount')
# Out:
# 4532
# discount will be 226.60000000000002

# %%
'sudh' == 'sudh'
# Out:
# True

# %%
a = 9
if a==9 :
    print('valid')
# Out:
# valid

# %% [raw]
# nested if

# %%
l = [1,2,3,4,5,6]
for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
s = 'sudh'
for i in s:
    print(i)
# Out:
# s
# u
# d
# h

# %%
t = (1,2,3,4,5,6,6)

# %%
for i in t:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 6

# %%
l = [1,4,5.6,4+7j,'sudh', True]
for i in l:
    print(type(i), 'type of', i)
# Out:
# <class 'int'> type of 1
# <class 'int'> type of 4
# <class 'float'> type of 5.6
# <class 'complex'> type of (4+7j)
# <class 'str'> type of sudh
# <class 'bool'> type of True

# %%
l = [1,4,5.6]
for i in l:
    print(i+2)
# Out:
# 3
# 6
# 7.6

# %%
l = [1,4,5.6]
l1=[]
for i in l:
    l1.append(i+2);
print(l1)
# Out:
# [3, 6, 7.6]

# %%
print(l1)
# Out:
# [3, 6, 7.6]

# %%
l = [1,4,5.6]
l1=[]
for i in l:
    i=i+2
    l1.append(i);
print(l1)
# Out:
# [3, 6, 7.6]

# %%
l = [2,45,78,12,'sudh',6+7j,[56,67,78]]
l2=[]
for i in l:
    if type(i) == int :
        l2.append(i);
print(l2)
# Out:
# [2, 45, 78, 12]

# %%
l = [2,45,78,12,'sudh',6+7j,[56,67,78]]
l2=[]
for i in l:
    if type(i) == list :
        for j in i:
            if type(j) ==int:
                
                l2.append(j);
print(l2)
# Out:
# [56, 67, 78]

# %%
l = [2,45,78,12,'sudh',6+7j,[56,67,78]]
l2=[]
for i in l:
    if type(i) == complex :
        l2.append(i);
print(l2)
# Out:
# [(6+7j)]

# %%
l = [2,45,78,12,'sudh',6+7j,[56,67,78]]
l2=[]
for i in l:
    l2.append(i)
    print(l2.index(i),'index value is', i)
# Out:
# 0 index value is 2
# 1 index value is 45
# 2 index value is 78
# 3 index value is 12
# 4 index value is sudh
# 5 index value is (6+7j)
# 6 index value is [56, 67, 78]

# %%
l = [2,45,78,12,'sudh','kumar',6+7j,[56,67,78]]
l2=[]
for i in l:
    if type(i) == str :
        for j in i:
            l2.append(j)
print(l2)
# Out:
# ['s', 'u', 'd', 'h', 'k', 'u', 'm', 'a', 'r']

# %%
l = [2,45,78,12,'sudh',6+7j,[56,67,78]]
l2=[]
for i in l:
    if type(i)==int:
        i=i**2
        l2.append(i)
print(l2)
# Out:
# [4, 2025, 6084, 144]

# %%
l = [2,45,78,12,'sudh',6+7j,[56,67,78]]
for i in range(len(l)):
    print('index', i , 'for an element' , l[i])
# Out:
# index 0 for an element 2
# index 1 for an element 45
# index 2 for an element 78
# index 3 for an element 12
# index 4 for an element sudh
# index 5 for an element (6+7j)
# index 6 for an element [56, 67, 78]

# %%
for i in enumerate(l):
    print(i)
# Out:
# (0, 2)
# (1, 45)
# (2, 78)
# (3, 12)
# (4, 'sudh')
# (5, (6+7j))
# (6, [56, 67, 78])

# %%
for i,j in enumerate(l):
    print(i,j)
# Out:
# 0 2
# 1 45
# 2 78
# 3 12
# 4 sudh
# 5 (6+7j)
# 6 [56, 67, 78]

# %%
l = [2,45,78,12,'sudh','kumar',6+7j,[56,67,78]]
for i in l:
    if type(i)== str:
        l1=[]
        for j in i:
            l1.append(j)
        print(l1)
# Out:
# ['s', 'u', 'd', 'h']
# ['k', 'u', 'm', 'a', 'r']

# %%
l = [2,45,78,12,'sudh','kumar',6+7j,[56,67,78]]
l2=[]
for i in l:
    if type(i)==int :
        l2.append(i**2)
print(l2)
# Out:
# [4, 2025, 6084, 144]
