# %%
class dict_parsing():
    
    def __init__(self,a):
        self.a = a
        
    def get_keys(self):
        if self.verify_dict() :
            return list(self.a.keys())
        
       
    def get_values(self):
        if self.verify_dict() :
            return list(self.a.values())
    
    def verify_dict(self):
            if type(self.a) !=dict:
                raise Exception('input is not dictionary' , self.a)
                
    def insertion(self,**kwargs):
        for k ,v in kwargs.items():
            self.a[k] = v
        return self.a

# %%
d = dict_parsing({'a': 5, 'b': 6, 'c': 7, 'h': '67'})

# %%
d.insertion(name = 'sudh')
# Out:
# {'a': 5, 'b': 6, 'c': 7, 'h': '67', 'name': 'sudh'}

# %%
d.insertion(t = 78)
# Out:
# {'a': 5, 'b': 6, 'c': 7, 'h': '67', 'name': 'sudh', 't': 78}

# %%
d.insertion(h = 56, mail_id = 'raksha@gmail.com' , mob_No = 4532)
# Out:
# {'a': 5,
#  'b': 6,
#  'c': 7,
#  'h': 56,
#  'name': 'sudh',
#  't': 78,
#  'mail_id': 'raksha@gmail.com',
#  'mob_No': 4532}

# %%
d.verify_dict()

# %%
d.get_keys()

# %%
d.get_values()

# %%
class dict_parsing():
    
    def __init__(self,a):
        if type(a)!= dict:
            raise Exception('input is not dictionary' , self.a)
        self.a = a
            
            
        
  #  def verify_dict(self):
     #   if type(self.a) !=dict:
      #      raise Exception('input is not dictionary' , self.a)
                
        
    def get_keys(self):
        for i in self.a.keys():
            print(i)
        
       
    def get_values(self):
        if self.verify_dict() :
            return list(self.a.values())
    

    def insertion(self,**kwargs):
        
        for k ,v in kwargs.items():
            self.a[k] = v
        return self.a

# %%
d = dict_parsing({'a': 5, 'b': 6, 'c': 7, 'h': '67'})

# %%
d.insertion()
# Out:
# {'a': 5, 'b': 6, 'c': 7, 'h': '67'}

# %%
d.get_keys()
# Out:
# a
# b
# c
# h

# %%
class dict_fun():
    def __init__(self,a):
        self.a = a
        
    def get_keys(self):
        if self.verify_input():
            return list(self.a.keys())
    
    def get_values(self):
        if self.verify_input():
            return self.a.values()
    
    def verify_input(self):
            if type(self.a) !=dict:
                raise Exception('input is not dictionary' , b)

# %%
d = dict_fun({'a': 5, 'b': 6, 'c': 7, 'h': '67'})

# %%
d.get_keys()

# %%
import mydict

# %%
mydict.Dict_function
# Out:
# mydict.Dict_function

# %%
a = mydict.Dict_function({'a': 5, 'b': 6, 'c': 7, 'h': '67'})

# %%
a.get_keys()
# Out:
# ['a', 'b', 'c', 'h']

# %%
a.get_values()
# Out:
# [5, 6, 7, '67']

# %%
from mydict import Dict_function

# %%
a = Dict_function({'a': 5, 'b': 6, 'c': 7, 'h': '67'})

# %%
a.get_values()
# Out:
# [5, 6, 7, '67']
